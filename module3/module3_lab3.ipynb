# %%
import pandas as pd

df = pd.read_csv("bridges.csv")

print(df.shape)
display(df.head())
print(df.dtypes)
# Out:
# (108, 13)
#    Id river  location  erected   purpose  length  lanes clear-g   t-or-d  \
# 0  E1     M       3.0     1818   HIGHWAY     NaN    2.0       N  THROUGH
# 1  E2     A      25.0     1819   HIGHWAY  1037.0    2.0       N  THROUGH
# 2  E3     A      39.0     1829  AQUEDUCT     NaN    1.0       N  THROUGH
# 3  E5     A      29.0     1837   HIGHWAY  1000.0    2.0       N  THROUGH
# 4  E6     M      23.0     1838   HIGHWAY     NaN    2.0       N  THROUGH
#
#   material   span rel-l  type
# 0     WOOD  SHORT     S  WOOD
# 1     WOOD  SHORT     S  WOOD
# 2     WOOD    NaN     S  WOOD
# 3     WOOD  SHORT     S  WOOD
# 4     WOOD    NaN     S  WOOD
# Id              str
# river           str
# location    float64
# erected       int64
# purpose         str
# length      float64
# lanes       float64
# clear-g         str
# t-or-d          str
# material        str
# span            str
# rel-l           str
# type            str
# dtype: object

# %% [markdown]
# Assumption
#
# I would assume that bridge lengths under 10,000 feet are possible. Anything over that will be flagged so I can look at it more closely.

# %%
df["length"].describe()
# Out:
# count      81.000000
# mean     1567.469136
# std       747.491523
# min       804.000000
# 25%      1000.000000
# 50%      1300.000000
# 75%      2000.000000
# max      4558.000000
# Name: length, dtype: float64

# %% [markdown]
# Flagged Values
#
# The values over 10,000 feet were flagged because they were outside the range I decided were possible. I did not automatically delete them as it was possible they were still real bridges. What I would do is to original source first before changing anything.

# %% [markdown]
# GitHub Repository:
# https://github.com/leonhong2007/cs82a-portfolio/tree/main/module3
